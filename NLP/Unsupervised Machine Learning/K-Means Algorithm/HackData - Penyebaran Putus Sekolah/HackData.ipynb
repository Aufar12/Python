# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
plt.style.use('ggplot')

df = pd.read_excel(r"C:\Users\Aufar\Desktop\edm\HackData\DataSD.xlsx")
df1 = pd.read_excel(r"C:\Users\Aufar\Desktop\edm\HackData\DataSMP.xlsx")
df2 = pd.read_excel(r"C:\Users\Aufar\Desktop\edm\HackData\DataSMA.xlsx")
df = df.dropna(axis=1, how='all')
df1 = df1.dropna(axis=1, how='all')
df2 = df2.dropna(axis=1, how='all')
df = df.dropna()
df1 = df1.dropna()
df2 = df2.dropna()

#df.head(34)

plt.rcParams['figure.figsize'] = (15, 20)
plt.barh(df['Provinsi'], df['Putus Sekolah'], align='center', alpha=0.5)
plt.ylabel('Jumlah Siswa Putus Sekolah Dasar')
plt.xlabel('Nama Provinsi')
plt.title('Grafik Putus Sekolah Dasar di provinsi Indonesia')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 20)
plt.barh(df['Provinsi'], df['Siswa'], align='center', alpha=0.5)
plt.ylabel('Jumlah Siswa Aktif Sekolah Dasar')
plt.xlabel('Nama Provinsi')
plt.title('Grafik Siswa Aktif Sekolah Dasar di provinsi Indonesia')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 20)
plt.barh(df1['Provinsi'], df1['Putus Sekolah'], align='center', alpha=0.5)
plt.ylabel('Jumlah Siswa Putus Sekolah Menengah Pertama')
plt.xlabel('Nama Provinsi')
plt.title('Grafik Putus Sekolah Menengah Pertama di provinsi Indonesia')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 20)
plt.barh(df1['Provinsi'], df1['Siswa'], align='center', alpha=0.5)
plt.ylabel('Jumlah Siswa Aktif Sekolah Menengah Pertama')
plt.xlabel('Nama Provinsi')
plt.title('Grafik Siswa Aktif Sekolah Menengah Pertama di provinsi Indonesia')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 20)
plt.barh(df2['Provinsi'], df2['Putus Sekolah'], align='center', alpha=0.5)
plt.ylabel('Jumlah Siswa Putus Sekolah Menengah Atas')
plt.xlabel('Nama Provinsi')
plt.title('Grafik Putus Sekolah Menengah Atas di provinsi Indonesia')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (15, 20)
plt.barh(df2['Provinsi'], df2['Siswa'], align='center', alpha=0.5)
plt.ylabel('Jumlah Siswa Aktif Sekolah Menengah Atas')
plt.xlabel('Nama Provinsi')
plt.title('Grafik Siswa Aktif Sekolah Menengah Atas di provinsi Indonesia')
plt.show()

# %%
# data = pd.read_json('http://ppid.jakarta.go.id/json?url=http://data.jakarta.go.id/dataset/894b6aa6-8d31-465d-affd-190c3866dbab/resource/155e20f3-3431-4e73-8c2e-3d2413adcfd0/download/Data-Jumlah-Sekolah-Guru-Murid-dan-Ruang-Kelas-Menurut-Jenis-Sekolah.csv') 
# print(data) 
df3 = pd.read_excel(r"C:\Users\Aufar\Desktop\edm\HackData\JumlahBerdasarkanJenis.xlsx")
plt.pie(df3['jumlah_murid'], labels=df3['tingkat_pendidikan'])
plt.show()
plt.rcParams['figure.figsize'] = (10, 10)

# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

df = pd.read_excel(r"C:\Users\Aufar\Desktop\edm\HackData\DummyNilai.xlsx")
df = df.dropna(axis=1, how='all')
df = df.drop(4)
df.head(77)

plt.bar(df['Pelajaran'], df['Nilai'], align='center', alpha=0.5, color='blue')
plt.ylabel('Nilai')
plt.xlabel('Ulangan ke-')
plt.title('Ulangan')
plt.show()
